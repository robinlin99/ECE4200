# %% [markdown]
# ### Setting up Training Data ###

# %%
import numpy as np
import h5py
import csv
import matplotlib.pyplot as plt
with h5py.File("data.hdf5", 'r') as f:
    train_data = f['train'][()]
    test_data = f['test'][()]
labels = open('train_labels.csv')
labels_reader = csv.reader(labels)
classes = ["FM","OQPSK","BPSK","8PSK","AM-SSB-SC","4ASK","16PSK","AM-DSB-SC","QPSK","OOK"]
train_labels_data = []
for row in labels_reader:
    if row[0] != 'Id':
        train_labels_data.append(classes.index(row[1]))

train_labels_data = np.asarray(train_labels_data)
print(train_data.shape)
print(len(train_labels_data))
print(test_data.shape)
# Out:
# (30000, 1024, 2)
# 30000
# (20000, 1024, 2)

# %% [markdown]
# ### Visualizing Data  ###

# %%
# for j in range(0,50):
#     I = []
#     Q = []
#     for i in range(0,1024):
#         I.append(train_data[j][i][0])
#         Q.append(train_data[j][i][1])
#     plt.figure(j)
#     plt.scatter(I,Q)

# %% [markdown]
# ### Setting up Convolutional Neural Network Architecture ###

# %%
from __future__ import print_function
import torch
from torch.nn import Linear, ReLU, CrossEntropyLoss, Sequential, Conv2d, MaxPool2d, Module, Softmax, BatchNorm2d, Dropout
from torch.optim import Adam, SGD
from torch.autograd import Variable
import torch.nn.functional as F
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import torchvision
from torchvision import datasets, transforms

# converting training images into torch format
train_x = train_data.reshape(30000, 1, 1024, 2)
train_x  = torch.from_numpy(train_x)

# train_fft_x = fft_train_2d.reshape(30000, 1, 1024, 2)
# train_fft_x  = torch.from_numpy(train_fft_x)

# converting test images into torch format
test_x = test_data.reshape(20000, 1, 1024, 2)
test_x  = torch.from_numpy(test_x)

# converting the target into torch format
train_y = train_labels_data.astype(int)
train_y = torch.from_numpy(train_y)


# split into batches
train_x, val_x, train_y, val_y = train_test_split(train_x, train_y, test_size = 0.1,shuffle=True)

train_x1, train_x2, train_y1,train_y2 = train_test_split(train_x, train_y, test_size = 0.50,shuffle=True)
train_x3, train_x4, train_y3,train_y4 = train_test_split(train_x1, train_y1, test_size = 0.50,shuffle=True)
train_x5, train_x6, train_y5,train_y6 = train_test_split(train_x2, train_y2, test_size = 0.7,shuffle=True)
# batches
train = torch.utils.data.TensorDataset(train_x,train_y)
trainloader = torch.utils.data.DataLoader(train, batch_size=120, shuffle=True)

# shape of training data
print(train_x.shape)
print(train_y.shape)

import torch.nn as nn

class Net1(nn.Module):
    def __init__(self):
        super(Net1, self).__init__()
        self.conv1 = nn.Conv2d(1, 5, kernel_size=(3,3), stride=1, padding=7)
        self.pool = nn.MaxPool2d(kernel_size=(2,2))
        self.conv2 = nn.Conv2d(5, 5, kernel_size=5, stride=1, padding=2)
        self.batchnorm = nn.BatchNorm2d(num_features=5)
        self.fc1 = nn.Linear(3885, 128)
        self.fc2 = nn.Linear(128, 32)
        self.fc3 = nn.Linear(32, len(classes))

    def forward(self, x):
        x = self.pool(F.selu(self.batchnorm(self.conv1(x))))
        x = self.pool(F.selu(self.batchnorm(self.conv2(x))))
        x = x.view(-1, 3885)
        x = F.selu((self.fc1(x)))
        x = F.selu((self.fc2(x)))
        x = self.fc3(x)
        return F.log_softmax(x, dim=1)
        
cnn = Net1()
print(cnn)

it = iter(trainloader)
# Out:
# torch.Size([27000, 1, 1024, 2])
# torch.Size([27000])
# Net1(
#   (conv1): Conv2d(1, 5, kernel_size=(3, 3), stride=(1, 1), padding=(7, 7))
#   (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(5, 5, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (batchnorm): BatchNorm2d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=3885, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=32, bias=True)
#   (fc3): Linear(in_features=32, out_features=10, bias=True)
# )

# %% [markdown]
# # Set up training protocol ###

# %%
def fit(model, train_loader):
    optimizer = torch.optim.Adam(model.parameters(),lr=0.0001,weight_decay = 0.03)
    error = nn.CrossEntropyLoss()
    EPOCHS = 10000
    model.train()
    for epoch in range(EPOCHS):
        for batch_idx, (X_batch, y_batch) in enumerate(train_loader):
            var_X_batch = Variable(X_batch).float()
            var_y_batch = Variable(y_batch)
            optimizer.zero_grad()
            output = model(var_X_batch)
            loss = error(output, var_y_batch)
            loss.backward()
            optimizer.step()
            predicted = torch.max(output.data, 1)[1] 
            print("Accuracy:")
            print(((predicted == var_y_batch).sum()).double()/120)
            print("Loss:")
            print(loss)
            print("Epoch:")
            print(epoch)
            print("Batch:")
            print(batch_idx)
            if (batch_idx % 30 == 0):
                with torch.no_grad():
                    validout = model(val_x)
                valpred = torch.max(validout.data, 1)[1] 
                print("Validation Accuracy:")
                print(((valpred == val_y).sum()).double()/3000)

# %%
fit(cnn,trainloader)
# Out:
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.2266, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 0
# Validation Accuracy:
# tensor(0.1587, dtype=torch.float64)
# Accuracy:
# tensor(0.1000, dtype=torch.float64)
# Loss:
# tensor(2.3336, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 1
# Accuracy:
# tensor(0.1583, dtype=torch.float64)
# Loss:
# tensor(2.2483, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 2
# Accuracy:
# tensor(0.1500, dtype=torch.float64)
# Loss:
# tensor(2.2342, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 3
# Accuracy:
# tensor(0.1750, dtype=torch.float64)
# Loss:
# tensor(2.2523, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 4
# Accuracy:
# tensor(0.1083, dtype=torch.float64)
# Loss:
# tensor(2.3106, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 5
# Accuracy:
# tensor(0.1333, dtype=torch.float64)
# Loss:
# tensor(2.2583, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 6
# Accuracy:
# tensor(0.2000, dtype=torch.float64)
# Loss:
# tensor(2.2108, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 7
# Accuracy:
# tensor(0.1583, dtype=torch.float64)
# Loss:
# tensor(2.2389, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 8
# Accuracy:
# tensor(0.1417, dtype=torch.float64)
# Loss:
# tensor(2.2006, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 9
# Accuracy:
# tensor(0.1250, dtype=torch.float64)
# Loss:
# tensor(2.2568, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 10
# Accuracy:
# tensor(0.1250, dtype=torch.float64)
# Loss:
# tensor(2.2921, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 11
# Accuracy:
# tensor(0.2250, dtype=torch.float64)
# Loss:
# tensor(2.1449, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 12
# Accuracy:
# tensor(0.1917, dtype=torch.float64)
# Loss:
# tensor(2.2384, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 13
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.1553, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 14
# Accuracy:
# tensor(0.1417, dtype=torch.float64)
# Loss:
# tensor(2.2166, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 15
# Accuracy:
# tensor(0.2250, dtype=torch.float64)
# Loss:
# tensor(2.2298, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 16
# Accuracy:
# tensor(0.1667, dtype=torch.float64)
# Loss:
# tensor(2.2054, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 17
# Accuracy:
# tensor(0.1333, dtype=torch.float64)
# Loss:
# tensor(2.2672, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 18
# Accuracy:
# tensor(0.1833, dtype=torch.float64)
# Loss:
# tensor(2.2213, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 19
# Accuracy:
# tensor(0.1417, dtype=torch.float64)
# Loss:
# tensor(2.2626, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 20
# Accuracy:
# tensor(0.1583, dtype=torch.float64)
# Loss:
# tensor(2.1837, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 21
# Accuracy:
# tensor(0.2000, dtype=torch.float64)
# Loss:
# tensor(2.2421, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 22
# Accuracy:
# tensor(0.1750, dtype=torch.float64)
# Loss:
# tensor(2.2143, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 23
# Accuracy:
# tensor(0.1917, dtype=torch.float64)
# Loss:
# tensor(2.2355, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 24
# Accuracy:
# tensor(0.1167, dtype=torch.float64)
# Loss:
# tensor(2.2393, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 25
# Accuracy:
# tensor(0.2000, dtype=torch.float64)
# Loss:
# tensor(2.1760, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 26
# Accuracy:
# tensor(0.2000, dtype=torch.float64)
# Loss:
# tensor(2.2082, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 27
# Accuracy:
# tensor(0.1417, dtype=torch.float64)
# Loss:
# tensor(2.2562, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 28
# Accuracy:
# tensor(0.1667, dtype=torch.float64)
# Loss:
# tensor(2.2444, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 29
# Accuracy:
# tensor(0.1917, dtype=torch.float64)
# Loss:
# tensor(2.2380, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 30
# Validation Accuracy:
# tensor(0.1580, dtype=torch.float64)
# Accuracy:
# tensor(0.2333, dtype=torch.float64)
# Loss:
# tensor(2.1761, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 31
# Accuracy:
# tensor(0.1417, dtype=torch.float64)
# Loss:
# tensor(2.2665, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 32
# Accuracy:
# tensor(0.1417, dtype=torch.float64)
# Loss:
# tensor(2.2221, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 33
# Accuracy:
# tensor(0.1583, dtype=torch.float64)
# Loss:
# tensor(2.1805, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 34
# Accuracy:
# tensor(0.2250, dtype=torch.float64)
# Loss:
# tensor(2.1630, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 35
# Accuracy:
# tensor(0.1667, dtype=torch.float64)
# Loss:
# tensor(2.2027, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 36
# Accuracy:
# tensor(0.1833, dtype=torch.float64)
# Loss:
# tensor(2.1843, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 37
# Accuracy:
# tensor(0.1583, dtype=torch.float64)
# Loss:
# tensor(2.1866, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 38
# Accuracy:
# tensor(0.1833, dtype=torch.float64)
# Loss:
# tensor(2.2233, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 39
# Accuracy:
# tensor(0.2667, dtype=torch.float64)
# Loss:
# tensor(2.1947, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 40
# Accuracy:
# tensor(0.1333, dtype=torch.float64)
# Loss:
# tensor(2.2215, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 41
# Accuracy:
# tensor(0.2250, dtype=torch.float64)
# Loss:
# tensor(2.1792, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 42
# Accuracy:
# tensor(0.2167, dtype=torch.float64)
# Loss:
# tensor(2.1274, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 43
# Accuracy:
# tensor(0.1917, dtype=torch.float64)
# Loss:
# tensor(2.2048, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 44
# Accuracy:
# tensor(0.1917, dtype=torch.float64)
# Loss:
# tensor(2.2057, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 45
# Accuracy:
# tensor(0.1917, dtype=torch.float64)
# Loss:
# tensor(2.2235, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 46
# Accuracy:
# tensor(0.2417, dtype=torch.float64)
# Loss:
# tensor(2.2018, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 47
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.1859, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 48
# Accuracy:
# tensor(0.2250, dtype=torch.float64)
# Loss:
# tensor(2.2335, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 49
# Accuracy:
# tensor(0.1833, dtype=torch.float64)
# Loss:
# tensor(2.1964, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 50
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.1878, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 51
# Accuracy:
# tensor(0.2000, dtype=torch.float64)
# Loss:
# tensor(2.2146, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 52
# Accuracy:
# tensor(0.1917, dtype=torch.float64)
# Loss:
# tensor(2.1966, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 53
# Accuracy:
# tensor(0.1917, dtype=torch.float64)
# Loss:
# tensor(2.2317, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 54
# Accuracy:
# tensor(0.1333, dtype=torch.float64)
# Loss:
# tensor(2.2520, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 55
# Accuracy:
# tensor(0.1500, dtype=torch.float64)
# Loss:
# tensor(2.2300, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 56
# Accuracy:
# tensor(0.1417, dtype=torch.float64)
# Loss:
# tensor(2.2343, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 57
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.1607, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 58
# Accuracy:
# tensor(0.1583, dtype=torch.float64)
# Loss:
# tensor(2.1599, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 59
# Accuracy:
# tensor(0.1250, dtype=torch.float64)
# Loss:
# tensor(2.2160, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 60
# Validation Accuracy:
# tensor(0.1540, dtype=torch.float64)
# Accuracy:
# tensor(0.1667, dtype=torch.float64)
# Loss:
# tensor(2.2066, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 61
# Accuracy:
# tensor(0.1083, dtype=torch.float64)
# Loss:
# tensor(2.2430, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 62
# Accuracy:
# tensor(0.2000, dtype=torch.float64)
# Loss:
# tensor(2.1693, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 63
# Accuracy:
# tensor(0.1750, dtype=torch.float64)
# Loss:
# tensor(2.2261, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 64
# Accuracy:
# tensor(0.1500, dtype=torch.float64)
# Loss:
# tensor(2.2410, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 65
# Accuracy:
# tensor(0.1750, dtype=torch.float64)
# Loss:
# tensor(2.1988, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 66
# Accuracy:
# tensor(0.1667, dtype=torch.float64)
# Loss:
# tensor(2.1897, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 67
# Accuracy:
# tensor(0.2417, dtype=torch.float64)
# Loss:
# tensor(2.1280, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 68
# Accuracy:
# tensor(0.1583, dtype=torch.float64)
# Loss:
# tensor(2.2229, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 69
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.1579, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 70
# Accuracy:
# tensor(0.1167, dtype=torch.float64)
# Loss:
# tensor(2.2208, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 71
# Accuracy:
# tensor(0.2250, dtype=torch.float64)
# Loss:
# tensor(2.1297, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 72
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.1860, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 73
# Accuracy:
# tensor(0.2250, dtype=torch.float64)
# Loss:
# tensor(2.1635, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 74
# Accuracy:
# tensor(0.2333, dtype=torch.float64)
# Loss:
# tensor(2.1058, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 75
# Accuracy:
# tensor(0.2417, dtype=torch.float64)
# Loss:
# tensor(2.1720, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 76
# Accuracy:
# tensor(0.1417, dtype=torch.float64)
# Loss:
# tensor(2.1724, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 77
# Accuracy:
# tensor(0.1750, dtype=torch.float64)
# Loss:
# tensor(2.1690, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 78
# Accuracy:
# tensor(0.1667, dtype=torch.float64)
# Loss:
# tensor(2.2310, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 79
# Accuracy:
# tensor(0.2583, dtype=torch.float64)
# Loss:
# tensor(2.1952, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 80
# Accuracy:
# tensor(0.1750, dtype=torch.float64)
# Loss:
# tensor(2.1667, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 81
# Accuracy:
# tensor(0.2167, dtype=torch.float64)
# Loss:
# tensor(2.1521, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 82
# Accuracy:
# tensor(0.1917, dtype=torch.float64)
# Loss:
# tensor(2.1984, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 83
# Accuracy:
# tensor(0.1500, dtype=torch.float64)
# Loss:
# tensor(2.2333, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 84
# Accuracy:
# tensor(0.2000, dtype=torch.float64)
# Loss:
# tensor(2.1668, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 85
# Accuracy:
# tensor(0.1750, dtype=torch.float64)
# Loss:
# tensor(2.1788, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 86
# Accuracy:
# tensor(0.1917, dtype=torch.float64)
# Loss:
# tensor(2.1900, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 87
# Accuracy:
# tensor(0.1083, dtype=torch.float64)
# Loss:
# tensor(2.2385, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 88
# Accuracy:
# tensor(0.1917, dtype=torch.float64)
# Loss:
# tensor(2.1736, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 89
# Accuracy:
# tensor(0.1750, dtype=torch.float64)
# Loss:
# tensor(2.1992, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 90
# Validation Accuracy:
# tensor(0.1797, dtype=torch.float64)
# Accuracy:
# tensor(0.2667, dtype=torch.float64)
# Loss:
# tensor(2.0460, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 91
# Accuracy:
# tensor(0.1667, dtype=torch.float64)
# Loss:
# tensor(2.2412, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 92
# Accuracy:
# tensor(0.1833, dtype=torch.float64)
# Loss:
# tensor(2.1466, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 93
# Accuracy:
# tensor(0.1833, dtype=torch.float64)
# Loss:
# tensor(2.1731, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 94
# Accuracy:
# tensor(0.1833, dtype=torch.float64)
# Loss:
# tensor(2.1958, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 95
# Accuracy:
# tensor(0.2750, dtype=torch.float64)
# Loss:
# tensor(2.0423, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 96
# Accuracy:
# tensor(0.1917, dtype=torch.float64)
# Loss:
# tensor(2.1749, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 97
# Accuracy:
# tensor(0.2000, dtype=torch.float64)
# Loss:
# tensor(2.1208, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 98
# Accuracy:
# tensor(0.1667, dtype=torch.float64)
# Loss:
# tensor(2.1807, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 99
# Accuracy:
# tensor(0.2000, dtype=torch.float64)
# Loss:
# tensor(2.1617, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 100
# Accuracy:
# tensor(0.1417, dtype=torch.float64)
# Loss:
# tensor(2.2142, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 101
# Accuracy:
# tensor(0.1917, dtype=torch.float64)
# Loss:
# tensor(2.1491, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 102
# Accuracy:
# tensor(0.1750, dtype=torch.float64)
# Loss:
# tensor(2.1930, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 103
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.1336, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 104
# Accuracy:
# tensor(0.2250, dtype=torch.float64)
# Loss:
# tensor(2.1084, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 105
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.1495, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 106
# Accuracy:
# tensor(0.1833, dtype=torch.float64)
# Loss:
# tensor(2.1372, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 107
# Accuracy:
# tensor(0.2417, dtype=torch.float64)
# Loss:
# tensor(2.1154, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 108
# Accuracy:
# tensor(0.1250, dtype=torch.float64)
# Loss:
# tensor(2.2069, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 109
# Accuracy:
# tensor(0.1500, dtype=torch.float64)
# Loss:
# tensor(2.1465, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 110
# Accuracy:
# tensor(0.0833, dtype=torch.float64)
# Loss:
# tensor(2.2384, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 111
# Accuracy:
# tensor(0.1500, dtype=torch.float64)
# Loss:
# tensor(2.2330, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 112
# Accuracy:
# tensor(0.1667, dtype=torch.float64)
# Loss:
# tensor(2.1265, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 113
# Accuracy:
# tensor(0.1833, dtype=torch.float64)
# Loss:
# tensor(2.1220, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 114
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.1388, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 115
# Accuracy:
# tensor(0.2583, dtype=torch.float64)
# Loss:
# tensor(2.0950, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 116
# Accuracy:
# tensor(0.1500, dtype=torch.float64)
# Loss:
# tensor(2.2062, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 117
# Accuracy:
# tensor(0.2417, dtype=torch.float64)
# Loss:
# tensor(2.1316, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 118
# Accuracy:
# tensor(0.2167, dtype=torch.float64)
# Loss:
# tensor(2.1861, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 119
# Accuracy:
# tensor(0.1500, dtype=torch.float64)
# Loss:
# tensor(2.2670, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 120
# Validation Accuracy:
# tensor(0.1957, dtype=torch.float64)
# Accuracy:
# tensor(0.2917, dtype=torch.float64)
# Loss:
# tensor(2.0805, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 121
# Accuracy:
# tensor(0.1500, dtype=torch.float64)
# Loss:
# tensor(2.1306, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 122
# Accuracy:
# tensor(0.1500, dtype=torch.float64)
# Loss:
# tensor(2.1629, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 123
# Accuracy:
# tensor(0.2417, dtype=torch.float64)
# Loss:
# tensor(2.0329, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 124
# Accuracy:
# tensor(0.1417, dtype=torch.float64)
# Loss:
# tensor(2.1738, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 125
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.1327, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 126
# Accuracy:
# tensor(0.2500, dtype=torch.float64)
# Loss:
# tensor(2.0276, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 127
# Accuracy:
# tensor(0.1750, dtype=torch.float64)
# Loss:
# tensor(2.1855, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 128
# Accuracy:
# tensor(0.1833, dtype=torch.float64)
# Loss:
# tensor(2.0785, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 129
# Accuracy:
# tensor(0.1583, dtype=torch.float64)
# Loss:
# tensor(2.2311, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 130
# Accuracy:
# tensor(0.1917, dtype=torch.float64)
# Loss:
# tensor(2.1157, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 131
# Accuracy:
# tensor(0.2167, dtype=torch.float64)
# Loss:
# tensor(2.0870, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 132
# Accuracy:
# tensor(0.1583, dtype=torch.float64)
# Loss:
# tensor(2.1412, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 133
# Accuracy:
# tensor(0.2917, dtype=torch.float64)
# Loss:
# tensor(2.0531, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 134
# Accuracy:
# tensor(0.2000, dtype=torch.float64)
# Loss:
# tensor(2.1848, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 135
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.0828, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 136
# Accuracy:
# tensor(0.1500, dtype=torch.float64)
# Loss:
# tensor(2.1731, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 137
# Accuracy:
# tensor(0.1917, dtype=torch.float64)
# Loss:
# tensor(2.1485, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 138
# Accuracy:
# tensor(0.2417, dtype=torch.float64)
# Loss:
# tensor(2.0178, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 139
# Accuracy:
# tensor(0.2250, dtype=torch.float64)
# Loss:
# tensor(2.1576, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 140
# Accuracy:
# tensor(0.1833, dtype=torch.float64)
# Loss:
# tensor(2.1743, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 141
# Accuracy:
# tensor(0.2000, dtype=torch.float64)
# Loss:
# tensor(2.1100, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 142
# Accuracy:
# tensor(0.2000, dtype=torch.float64)
# Loss:
# tensor(2.1463, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 143
# Accuracy:
# tensor(0.1750, dtype=torch.float64)
# Loss:
# tensor(2.1911, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 144
# Accuracy:
# tensor(0.1583, dtype=torch.float64)
# Loss:
# tensor(2.1950, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 145
# Accuracy:
# tensor(0.2833, dtype=torch.float64)
# Loss:
# tensor(2.0537, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 146
# Accuracy:
# tensor(0.2250, dtype=torch.float64)
# Loss:
# tensor(2.1306, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 147
# Accuracy:
# tensor(0.1500, dtype=torch.float64)
# Loss:
# tensor(2.1477, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 148
# Accuracy:
# tensor(0.1833, dtype=torch.float64)
# Loss:
# tensor(2.0944, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 149
# Accuracy:
# tensor(0.1667, dtype=torch.float64)
# Loss:
# tensor(2.1392, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 150
# Validation Accuracy:
# tensor(0.2033, dtype=torch.float64)
# Accuracy:
# tensor(0.1583, dtype=torch.float64)
# Loss:
# tensor(2.1841, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 151
# Accuracy:
# tensor(0.2750, dtype=torch.float64)
# Loss:
# tensor(2.0080, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 152
# Accuracy:
# tensor(0.2417, dtype=torch.float64)
# Loss:
# tensor(2.0595, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 153
# Accuracy:
# tensor(0.2417, dtype=torch.float64)
# Loss:
# tensor(2.0637, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 154
# Accuracy:
# tensor(0.1167, dtype=torch.float64)
# Loss:
# tensor(2.1941, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 155
# Accuracy:
# tensor(0.3250, dtype=torch.float64)
# Loss:
# tensor(1.9843, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 156
# Accuracy:
# tensor(0.2500, dtype=torch.float64)
# Loss:
# tensor(2.0874, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 157
# Accuracy:
# tensor(0.1667, dtype=torch.float64)
# Loss:
# tensor(2.0831, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 158
# Accuracy:
# tensor(0.1917, dtype=torch.float64)
# Loss:
# tensor(2.1156, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 159
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.1379, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 160
# Accuracy:
# tensor(0.1167, dtype=torch.float64)
# Loss:
# tensor(2.1717, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 161
# Accuracy:
# tensor(0.1667, dtype=torch.float64)
# Loss:
# tensor(2.1580, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 162
# Accuracy:
# tensor(0.1833, dtype=torch.float64)
# Loss:
# tensor(2.0652, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 163
# Accuracy:
# tensor(0.1417, dtype=torch.float64)
# Loss:
# tensor(2.1586, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 164
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.1369, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 165
# Accuracy:
# tensor(0.1750, dtype=torch.float64)
# Loss:
# tensor(2.1189, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 166
# Accuracy:
# tensor(0.1667, dtype=torch.float64)
# Loss:
# tensor(2.1744, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 167
# Accuracy:
# tensor(0.2000, dtype=torch.float64)
# Loss:
# tensor(2.1729, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 168
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.1969, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 169
# Accuracy:
# tensor(0.2000, dtype=torch.float64)
# Loss:
# tensor(2.1347, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 170
# Accuracy:
# tensor(0.2000, dtype=torch.float64)
# Loss:
# tensor(2.1375, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 171
# Accuracy:
# tensor(0.1750, dtype=torch.float64)
# Loss:
# tensor(2.1276, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 172
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.1778, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 173
# Accuracy:
# tensor(0.2000, dtype=torch.float64)
# Loss:
# tensor(2.1661, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 174
# Accuracy:
# tensor(0.2917, dtype=torch.float64)
# Loss:
# tensor(2.0811, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 175
# Accuracy:
# tensor(0.1917, dtype=torch.float64)
# Loss:
# tensor(2.1348, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 176
# Accuracy:
# tensor(0.3333, dtype=torch.float64)
# Loss:
# tensor(2.0135, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 177
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.1208, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 178
# Accuracy:
# tensor(0.1833, dtype=torch.float64)
# Loss:
# tensor(2.1426, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 179
# Accuracy:
# tensor(0.3000, dtype=torch.float64)
# Loss:
# tensor(2.0630, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 180
# Validation Accuracy:
# tensor(0.1920, dtype=torch.float64)
# Accuracy:
# tensor(0.1833, dtype=torch.float64)
# Loss:
# tensor(2.1630, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 181
# Accuracy:
# tensor(0.2000, dtype=torch.float64)
# Loss:
# tensor(2.1427, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 182
# Accuracy:
# tensor(0.1750, dtype=torch.float64)
# Loss:
# tensor(2.1676, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 183
# Accuracy:
# tensor(0.2167, dtype=torch.float64)
# Loss:
# tensor(2.1097, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 184
# Accuracy:
# tensor(0.2667, dtype=torch.float64)
# Loss:
# tensor(2.0600, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 185
# Accuracy:
# tensor(0.2750, dtype=torch.float64)
# Loss:
# tensor(2.0362, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 186
# Accuracy:
# tensor(0.2000, dtype=torch.float64)
# Loss:
# tensor(2.1054, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 187
# Accuracy:
# tensor(0.1917, dtype=torch.float64)
# Loss:
# tensor(2.1270, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 188
# Accuracy:
# tensor(0.2333, dtype=torch.float64)
# Loss:
# tensor(2.0978, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 189
# Accuracy:
# tensor(0.2333, dtype=torch.float64)
# Loss:
# tensor(2.1036, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 190
# Accuracy:
# tensor(0.2000, dtype=torch.float64)
# Loss:
# tensor(2.0786, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 191
# Accuracy:
# tensor(0.1917, dtype=torch.float64)
# Loss:
# tensor(2.0949, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 192
# Accuracy:
# tensor(0.1917, dtype=torch.float64)
# Loss:
# tensor(2.1308, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 193
# Accuracy:
# tensor(0.2417, dtype=torch.float64)
# Loss:
# tensor(2.1613, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 194
# Accuracy:
# tensor(0.2500, dtype=torch.float64)
# Loss:
# tensor(2.1052, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 195
# Accuracy:
# tensor(0.2583, dtype=torch.float64)
# Loss:
# tensor(2.0960, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 196
# Accuracy:
# tensor(0.2583, dtype=torch.float64)
# Loss:
# tensor(2.0996, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 197
# Accuracy:
# tensor(0.1667, dtype=torch.float64)
# Loss:
# tensor(2.1690, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 198
# Accuracy:
# tensor(0.1917, dtype=torch.float64)
# Loss:
# tensor(2.0869, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 199
# Accuracy:
# tensor(0.1500, dtype=torch.float64)
# Loss:
# tensor(2.1633, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 200
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.1748, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 201
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.1105, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 202
# Accuracy:
# tensor(0.1500, dtype=torch.float64)
# Loss:
# tensor(2.1375, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 203
# Accuracy:
# tensor(0.1833, dtype=torch.float64)
# Loss:
# tensor(2.0938, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 204
# Accuracy:
# tensor(0.2000, dtype=torch.float64)
# Loss:
# tensor(2.1648, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 205
# Accuracy:
# tensor(0.1833, dtype=torch.float64)
# Loss:
# tensor(2.1492, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 206
# Accuracy:
# tensor(0.2333, dtype=torch.float64)
# Loss:
# tensor(2.0492, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 207
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.0871, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 208
# Accuracy:
# tensor(0.2167, dtype=torch.float64)
# Loss:
# tensor(2.0486, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 209
# Accuracy:
# tensor(0.2833, dtype=torch.float64)
# Loss:
# tensor(2.0218, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 210
# Validation Accuracy:
# tensor(0.2020, dtype=torch.float64)
# Accuracy:
# tensor(0.2167, dtype=torch.float64)
# Loss:
# tensor(2.1382, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 211
# Accuracy:
# tensor(0.2500, dtype=torch.float64)
# Loss:
# tensor(2.0598, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 212
# Accuracy:
# tensor(0.2583, dtype=torch.float64)
# Loss:
# tensor(2.1187, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 213
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.1197, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 214
# Accuracy:
# tensor(0.2500, dtype=torch.float64)
# Loss:
# tensor(2.0896, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 215
# Accuracy:
# tensor(0.2667, dtype=torch.float64)
# Loss:
# tensor(2.0320, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 216
# Accuracy:
# tensor(0.1583, dtype=torch.float64)
# Loss:
# tensor(2.1119, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 217
# Accuracy:
# tensor(0.2167, dtype=torch.float64)
# Loss:
# tensor(2.1224, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 218
# Accuracy:
# tensor(0.2500, dtype=torch.float64)
# Loss:
# tensor(2.1015, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 219
# Accuracy:
# tensor(0.2417, dtype=torch.float64)
# Loss:
# tensor(2.1400, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 220
# Accuracy:
# tensor(0.1833, dtype=torch.float64)
# Loss:
# tensor(2.1215, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 221
# Accuracy:
# tensor(0.1917, dtype=torch.float64)
# Loss:
# tensor(2.1700, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 222
# Accuracy:
# tensor(0.1833, dtype=torch.float64)
# Loss:
# tensor(2.1264, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 223
# Accuracy:
# tensor(0.2750, dtype=torch.float64)
# Loss:
# tensor(2.0919, grad_fn=<NllLossBackward>)
# Epoch:
# 0
# Batch:
# 224
# Accuracy:
# tensor(0.2750, dtype=torch.float64)
# Loss:
# tensor(2.0720, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 0
# Validation Accuracy:
# tensor(0.2057, dtype=torch.float64)
# Accuracy:
# tensor(0.2667, dtype=torch.float64)
# Loss:
# tensor(2.1008, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 1
# Accuracy:
# tensor(0.2500, dtype=torch.float64)
# Loss:
# tensor(2.0067, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 2
# Accuracy:
# tensor(0.2000, dtype=torch.float64)
# Loss:
# tensor(2.1540, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 3
# Accuracy:
# tensor(0.1917, dtype=torch.float64)
# Loss:
# tensor(2.1009, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 4
# Accuracy:
# tensor(0.1833, dtype=torch.float64)
# Loss:
# tensor(2.0914, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 5
# Accuracy:
# tensor(0.2167, dtype=torch.float64)
# Loss:
# tensor(2.0664, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 6
# Accuracy:
# tensor(0.2750, dtype=torch.float64)
# Loss:
# tensor(2.0352, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 7
# Accuracy:
# tensor(0.3167, dtype=torch.float64)
# Loss:
# tensor(2.0232, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 8
# Accuracy:
# tensor(0.3083, dtype=torch.float64)
# Loss:
# tensor(2.0648, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 9
# Accuracy:
# tensor(0.1917, dtype=torch.float64)
# Loss:
# tensor(2.1788, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 10
# Accuracy:
# tensor(0.3000, dtype=torch.float64)
# Loss:
# tensor(2.0528, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 11
# Accuracy:
# tensor(0.2500, dtype=torch.float64)
# Loss:
# tensor(2.0860, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 12
# Accuracy:
# tensor(0.2167, dtype=torch.float64)
# Loss:
# tensor(2.0750, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 13
# Accuracy:
# tensor(0.2750, dtype=torch.float64)
# Loss:
# tensor(1.9999, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 14
# Accuracy:
# tensor(0.2500, dtype=torch.float64)
# Loss:
# tensor(2.0448, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 15
# Accuracy:
# tensor(0.2417, dtype=torch.float64)
# Loss:
# tensor(2.0195, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 16
# Accuracy:
# tensor(0.2250, dtype=torch.float64)
# Loss:
# tensor(2.1208, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 17
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.0247, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 18
# Accuracy:
# tensor(0.3167, dtype=torch.float64)
# Loss:
# tensor(2.0318, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 19
# Accuracy:
# tensor(0.3000, dtype=torch.float64)
# Loss:
# tensor(1.9621, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 20
# Accuracy:
# tensor(0.2333, dtype=torch.float64)
# Loss:
# tensor(2.0970, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 21
# Accuracy:
# tensor(0.2750, dtype=torch.float64)
# Loss:
# tensor(2.0467, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 22
# Accuracy:
# tensor(0.2333, dtype=torch.float64)
# Loss:
# tensor(2.1190, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 23
# Accuracy:
# tensor(0.3583, dtype=torch.float64)
# Loss:
# tensor(1.9681, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 24
# Accuracy:
# tensor(0.3000, dtype=torch.float64)
# Loss:
# tensor(2.0166, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 25
# Accuracy:
# tensor(0.2500, dtype=torch.float64)
# Loss:
# tensor(2.0614, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 26
# Accuracy:
# tensor(0.3333, dtype=torch.float64)
# Loss:
# tensor(2.0768, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 27
# Accuracy:
# tensor(0.2583, dtype=torch.float64)
# Loss:
# tensor(2.0163, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 28
# Accuracy:
# tensor(0.2333, dtype=torch.float64)
# Loss:
# tensor(2.0689, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 29
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.1257, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 30
# Validation Accuracy:
# tensor(0.2100, dtype=torch.float64)
# Accuracy:
# tensor(0.2750, dtype=torch.float64)
# Loss:
# tensor(2.0350, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 31
# Accuracy:
# tensor(0.2667, dtype=torch.float64)
# Loss:
# tensor(2.0666, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 32
# Accuracy:
# tensor(0.1917, dtype=torch.float64)
# Loss:
# tensor(2.0903, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 33
# Accuracy:
# tensor(0.2417, dtype=torch.float64)
# Loss:
# tensor(2.0313, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 34
# Accuracy:
# tensor(0.1833, dtype=torch.float64)
# Loss:
# tensor(2.0908, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 35
# Accuracy:
# tensor(0.2667, dtype=torch.float64)
# Loss:
# tensor(2.0511, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 36
# Accuracy:
# tensor(0.2667, dtype=torch.float64)
# Loss:
# tensor(2.0341, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 37
# Accuracy:
# tensor(0.2417, dtype=torch.float64)
# Loss:
# tensor(2.0920, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 38
# Accuracy:
# tensor(0.2583, dtype=torch.float64)
# Loss:
# tensor(2.0903, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 39
# Accuracy:
# tensor(0.3167, dtype=torch.float64)
# Loss:
# tensor(1.9681, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 40
# Accuracy:
# tensor(0.1833, dtype=torch.float64)
# Loss:
# tensor(2.1411, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 41
# Accuracy:
# tensor(0.2250, dtype=torch.float64)
# Loss:
# tensor(2.1336, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 42
# Accuracy:
# tensor(0.2333, dtype=torch.float64)
# Loss:
# tensor(2.0596, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 43
# Accuracy:
# tensor(0.2833, dtype=torch.float64)
# Loss:
# tensor(1.9633, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 44
# Accuracy:
# tensor(0.2917, dtype=torch.float64)
# Loss:
# tensor(2.0186, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 45
# Accuracy:
# tensor(0.2000, dtype=torch.float64)
# Loss:
# tensor(2.1269, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 46
# Accuracy:
# tensor(0.1917, dtype=torch.float64)
# Loss:
# tensor(2.0579, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 47
# Accuracy:
# tensor(0.2333, dtype=torch.float64)
# Loss:
# tensor(2.0658, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 48
# Accuracy:
# tensor(0.1917, dtype=torch.float64)
# Loss:
# tensor(2.1139, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 49
# Accuracy:
# tensor(0.1750, dtype=torch.float64)
# Loss:
# tensor(2.0990, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 50
# Accuracy:
# tensor(0.2750, dtype=torch.float64)
# Loss:
# tensor(1.9866, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 51
# Accuracy:
# tensor(0.2333, dtype=torch.float64)
# Loss:
# tensor(2.0922, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 52
# Accuracy:
# tensor(0.2250, dtype=torch.float64)
# Loss:
# tensor(2.0524, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 53
# Accuracy:
# tensor(0.2167, dtype=torch.float64)
# Loss:
# tensor(2.0743, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 54
# Accuracy:
# tensor(0.2000, dtype=torch.float64)
# Loss:
# tensor(2.0959, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 55
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.0815, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 56
# Accuracy:
# tensor(0.2583, dtype=torch.float64)
# Loss:
# tensor(2.1153, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 57
# Accuracy:
# tensor(0.2333, dtype=torch.float64)
# Loss:
# tensor(2.1005, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 58
# Accuracy:
# tensor(0.2583, dtype=torch.float64)
# Loss:
# tensor(1.9762, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 59
# Accuracy:
# tensor(0.2667, dtype=torch.float64)
# Loss:
# tensor(2.0289, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 60
# Validation Accuracy:
# tensor(0.2117, dtype=torch.float64)
# Accuracy:
# tensor(0.2250, dtype=torch.float64)
# Loss:
# tensor(2.1137, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 61
# Accuracy:
# tensor(0.2667, dtype=torch.float64)
# Loss:
# tensor(2.0642, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 62
# Accuracy:
# tensor(0.2167, dtype=torch.float64)
# Loss:
# tensor(2.1392, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 63
# Accuracy:
# tensor(0.2750, dtype=torch.float64)
# Loss:
# tensor(2.0186, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 64
# Accuracy:
# tensor(0.2333, dtype=torch.float64)
# Loss:
# tensor(2.0926, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 65
# Accuracy:
# tensor(0.2583, dtype=torch.float64)
# Loss:
# tensor(1.9913, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 66
# Accuracy:
# tensor(0.2333, dtype=torch.float64)
# Loss:
# tensor(2.1041, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 67
# Accuracy:
# tensor(0.3333, dtype=torch.float64)
# Loss:
# tensor(1.8547, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 68
# Accuracy:
# tensor(0.1833, dtype=torch.float64)
# Loss:
# tensor(2.0741, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 69
# Accuracy:
# tensor(0.2667, dtype=torch.float64)
# Loss:
# tensor(2.0871, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 70
# Accuracy:
# tensor(0.2750, dtype=torch.float64)
# Loss:
# tensor(1.9874, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 71
# Accuracy:
# tensor(0.2583, dtype=torch.float64)
# Loss:
# tensor(2.0476, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 72
# Accuracy:
# tensor(0.2750, dtype=torch.float64)
# Loss:
# tensor(2.0637, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 73
# Accuracy:
# tensor(0.2583, dtype=torch.float64)
# Loss:
# tensor(2.0409, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 74
# Accuracy:
# tensor(0.2667, dtype=torch.float64)
# Loss:
# tensor(2.0174, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 75
# Accuracy:
# tensor(0.2000, dtype=torch.float64)
# Loss:
# tensor(2.1357, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 76
# Accuracy:
# tensor(0.1833, dtype=torch.float64)
# Loss:
# tensor(2.1084, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 77
# Accuracy:
# tensor(0.2750, dtype=torch.float64)
# Loss:
# tensor(1.9580, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 78
# Accuracy:
# tensor(0.2000, dtype=torch.float64)
# Loss:
# tensor(1.9822, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 79
# Accuracy:
# tensor(0.2167, dtype=torch.float64)
# Loss:
# tensor(2.0731, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 80
# Accuracy:
# tensor(0.1750, dtype=torch.float64)
# Loss:
# tensor(2.0884, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 81
# Accuracy:
# tensor(0.2250, dtype=torch.float64)
# Loss:
# tensor(2.0718, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 82
# Accuracy:
# tensor(0.2750, dtype=torch.float64)
# Loss:
# tensor(2.0493, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 83
# Accuracy:
# tensor(0.2667, dtype=torch.float64)
# Loss:
# tensor(2.0355, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 84
# Accuracy:
# tensor(0.2583, dtype=torch.float64)
# Loss:
# tensor(2.0573, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 85
# Accuracy:
# tensor(0.2667, dtype=torch.float64)
# Loss:
# tensor(2.0179, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 86
# Accuracy:
# tensor(0.2583, dtype=torch.float64)
# Loss:
# tensor(2.0251, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 87
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.0529, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 88
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.0232, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 89
# Accuracy:
# tensor(0.2750, dtype=torch.float64)
# Loss:
# tensor(2.0231, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 90
# Validation Accuracy:
# tensor(0.2263, dtype=torch.float64)
# Accuracy:
# tensor(0.2667, dtype=torch.float64)
# Loss:
# tensor(1.9871, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 91
# Accuracy:
# tensor(0.2167, dtype=torch.float64)
# Loss:
# tensor(2.0708, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 92
# Accuracy:
# tensor(0.2583, dtype=torch.float64)
# Loss:
# tensor(1.9943, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 93
# Accuracy:
# tensor(0.2333, dtype=torch.float64)
# Loss:
# tensor(2.0807, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 94
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.0659, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 95
# Accuracy:
# tensor(0.3083, dtype=torch.float64)
# Loss:
# tensor(2.0117, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 96
# Accuracy:
# tensor(0.2250, dtype=torch.float64)
# Loss:
# tensor(2.0241, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 97
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.0580, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 98
# Accuracy:
# tensor(0.2917, dtype=torch.float64)
# Loss:
# tensor(1.9921, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 99
# Accuracy:
# tensor(0.2250, dtype=torch.float64)
# Loss:
# tensor(2.0098, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 100
# Accuracy:
# tensor(0.2583, dtype=torch.float64)
# Loss:
# tensor(1.9759, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 101
# Accuracy:
# tensor(0.3000, dtype=torch.float64)
# Loss:
# tensor(1.9963, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 102
# Accuracy:
# tensor(0.2167, dtype=torch.float64)
# Loss:
# tensor(2.1070, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 103
# Accuracy:
# tensor(0.2417, dtype=torch.float64)
# Loss:
# tensor(2.0022, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 104
# Accuracy:
# tensor(0.2500, dtype=torch.float64)
# Loss:
# tensor(1.9995, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 105
# Accuracy:
# tensor(0.2667, dtype=torch.float64)
# Loss:
# tensor(2.0618, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 106
# Accuracy:
# tensor(0.3000, dtype=torch.float64)
# Loss:
# tensor(1.9909, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 107
# Accuracy:
# tensor(0.3000, dtype=torch.float64)
# Loss:
# tensor(2.0192, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 108
# Accuracy:
# tensor(0.2667, dtype=torch.float64)
# Loss:
# tensor(2.0418, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 109
# Accuracy:
# tensor(0.3000, dtype=torch.float64)
# Loss:
# tensor(2.0262, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 110
# Accuracy:
# tensor(0.2750, dtype=torch.float64)
# Loss:
# tensor(1.9837, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 111
# Accuracy:
# tensor(0.3000, dtype=torch.float64)
# Loss:
# tensor(2.0221, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 112
# Accuracy:
# tensor(0.2333, dtype=torch.float64)
# Loss:
# tensor(2.0595, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 113
# Accuracy:
# tensor(0.2250, dtype=torch.float64)
# Loss:
# tensor(1.9933, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 114
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.0728, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 115
# Accuracy:
# tensor(0.2750, dtype=torch.float64)
# Loss:
# tensor(2.0257, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 116
# Accuracy:
# tensor(0.2500, dtype=torch.float64)
# Loss:
# tensor(1.9905, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 117
# Accuracy:
# tensor(0.2667, dtype=torch.float64)
# Loss:
# tensor(2.0465, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 118
# Accuracy:
# tensor(0.2667, dtype=torch.float64)
# Loss:
# tensor(1.9469, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 119
# Accuracy:
# tensor(0.2333, dtype=torch.float64)
# Loss:
# tensor(2.0440, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 120
# Validation Accuracy:
# tensor(0.2090, dtype=torch.float64)
# Accuracy:
# tensor(0.2250, dtype=torch.float64)
# Loss:
# tensor(2.0611, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 121
# Accuracy:
# tensor(0.2500, dtype=torch.float64)
# Loss:
# tensor(2.0144, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 122
# Accuracy:
# tensor(0.2917, dtype=torch.float64)
# Loss:
# tensor(1.9850, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 123
# Accuracy:
# tensor(0.3417, dtype=torch.float64)
# Loss:
# tensor(1.8936, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 124
# Accuracy:
# tensor(0.2417, dtype=torch.float64)
# Loss:
# tensor(2.1223, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 125
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.1105, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 126
# Accuracy:
# tensor(0.1667, dtype=torch.float64)
# Loss:
# tensor(2.1070, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 127
# Accuracy:
# tensor(0.2083, dtype=torch.float64)
# Loss:
# tensor(2.0895, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 128
# Accuracy:
# tensor(0.2333, dtype=torch.float64)
# Loss:
# tensor(1.9945, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 129
# Accuracy:
# tensor(0.2583, dtype=torch.float64)
# Loss:
# tensor(2.0184, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 130
# Accuracy:
# tensor(0.2500, dtype=torch.float64)
# Loss:
# tensor(2.0184, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 131
# Accuracy:
# tensor(0.2167, dtype=torch.float64)
# Loss:
# tensor(2.1491, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 132
# Accuracy:
# tensor(0.1750, dtype=torch.float64)
# Loss:
# tensor(1.9848, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 133
# Accuracy:
# tensor(0.3083, dtype=torch.float64)
# Loss:
# tensor(2.0168, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 134
# Accuracy:
# tensor(0.2667, dtype=torch.float64)
# Loss:
# tensor(1.9667, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 135
# Accuracy:
# tensor(0.2583, dtype=torch.float64)
# Loss:
# tensor(2.0637, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 136
# Accuracy:
# tensor(0.2250, dtype=torch.float64)
# Loss:
# tensor(2.0083, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 137
# Accuracy:
# tensor(0.2833, dtype=torch.float64)
# Loss:
# tensor(1.9946, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 138
# Accuracy:
# tensor(0.1667, dtype=torch.float64)
# Loss:
# tensor(2.0496, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 139
# Accuracy:
# tensor(0.2417, dtype=torch.float64)
# Loss:
# tensor(2.0149, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 140
# Accuracy:
# tensor(0.3000, dtype=torch.float64)
# Loss:
# tensor(2.0545, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 141
# Accuracy:
# tensor(0.2250, dtype=torch.float64)
# Loss:
# tensor(2.0477, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 142
# Accuracy:
# tensor(0.2250, dtype=torch.float64)
# Loss:
# tensor(2.0454, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 143
# Accuracy:
# tensor(0.2917, dtype=torch.float64)
# Loss:
# tensor(1.9726, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 144
# Accuracy:
# tensor(0.2667, dtype=torch.float64)
# Loss:
# tensor(2.0310, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 145
# Accuracy:
# tensor(0.2417, dtype=torch.float64)
# Loss:
# tensor(2.0633, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 146
# Accuracy:
# tensor(0.2167, dtype=torch.float64)
# Loss:
# tensor(2.0212, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 147
# Accuracy:
# tensor(0.2917, dtype=torch.float64)
# Loss:
# tensor(1.9598, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 148
# Accuracy:
# tensor(0.2667, dtype=torch.float64)
# Loss:
# tensor(2.0207, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 149
# Accuracy:
# tensor(0.2417, dtype=torch.float64)
# Loss:
# tensor(2.0066, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 150
# Validation Accuracy:
# tensor(0.2390, dtype=torch.float64)
# Accuracy:
# tensor(0.2833, dtype=torch.float64)
# Loss:
# tensor(1.9696, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 151
# Accuracy:
# tensor(0.1917, dtype=torch.float64)
# Loss:
# tensor(2.0623, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 152
# Accuracy:
# tensor(0.2917, dtype=torch.float64)
# Loss:
# tensor(1.9347, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 153
# Accuracy:
# tensor(0.2917, dtype=torch.float64)
# Loss:
# tensor(1.9588, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 154
# Accuracy:
# tensor(0.2583, dtype=torch.float64)
# Loss:
# tensor(1.9685, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 155
# Accuracy:
# tensor(0.2750, dtype=torch.float64)
# Loss:
# tensor(2.0211, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 156
# Accuracy:
# tensor(0.2750, dtype=torch.float64)
# Loss:
# tensor(1.9921, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 157
# Accuracy:
# tensor(0.2750, dtype=torch.float64)
# Loss:
# tensor(2.0423, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 158
# Accuracy:
# tensor(0.2750, dtype=torch.float64)
# Loss:
# tensor(1.9259, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 159
# Accuracy:
# tensor(0.3667, dtype=torch.float64)
# Loss:
# tensor(1.9363, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 160
# Accuracy:
# tensor(0.2167, dtype=torch.float64)
# Loss:
# tensor(2.0765, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 161
# Accuracy:
# tensor(0.2750, dtype=torch.float64)
# Loss:
# tensor(2.0363, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 162
# Accuracy:
# tensor(0.2500, dtype=torch.float64)
# Loss:
# tensor(1.9870, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 163
# Accuracy:
# tensor(0.2667, dtype=torch.float64)
# Loss:
# tensor(1.9669, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 164
# Accuracy:
# tensor(0.2167, dtype=torch.float64)
# Loss:
# tensor(2.1168, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 165
# Accuracy:
# tensor(0.2917, dtype=torch.float64)
# Loss:
# tensor(1.8703, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 166
# Accuracy:
# tensor(0.3417, dtype=torch.float64)
# Loss:
# tensor(1.9486, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 167
# Accuracy:
# tensor(0.2417, dtype=torch.float64)
# Loss:
# tensor(1.9757, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 168
# Accuracy:
# tensor(0.3000, dtype=torch.float64)
# Loss:
# tensor(2.0028, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 169
# Accuracy:
# tensor(0.2667, dtype=torch.float64)
# Loss:
# tensor(2.0099, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 170
# Accuracy:
# tensor(0.2333, dtype=torch.float64)
# Loss:
# tensor(2.0982, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 171
# Accuracy:
# tensor(0.1917, dtype=torch.float64)
# Loss:
# tensor(2.0290, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 172
# Accuracy:
# tensor(0.3167, dtype=torch.float64)
# Loss:
# tensor(1.9575, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 173
# Accuracy:
# tensor(0.3167, dtype=torch.float64)
# Loss:
# tensor(1.9654, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 174
# Accuracy:
# tensor(0.2333, dtype=torch.float64)
# Loss:
# tensor(2.0748, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 175
# Accuracy:
# tensor(0.3333, dtype=torch.float64)
# Loss:
# tensor(1.8697, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 176
# Accuracy:
# tensor(0.3583, dtype=torch.float64)
# Loss:
# tensor(1.9062, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 177
# Accuracy:
# tensor(0.2833, dtype=torch.float64)
# Loss:
# tensor(1.9675, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 178
# Accuracy:
# tensor(0.3417, dtype=torch.float64)
# Loss:
# tensor(1.9084, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 179
# Accuracy:
# tensor(0.2250, dtype=torch.float64)
# Loss:
# tensor(2.0622, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 180
# Validation Accuracy:
# tensor(0.2283, dtype=torch.float64)
# Accuracy:
# tensor(0.2583, dtype=torch.float64)
# Loss:
# tensor(2.0015, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 181
# Accuracy:
# tensor(0.2000, dtype=torch.float64)
# Loss:
# tensor(2.1376, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 182
# Accuracy:
# tensor(0.3000, dtype=torch.float64)
# Loss:
# tensor(1.9486, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 183
# Accuracy:
# tensor(0.2583, dtype=torch.float64)
# Loss:
# tensor(1.9820, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 184
# Accuracy:
# tensor(0.2417, dtype=torch.float64)
# Loss:
# tensor(1.9940, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 185
# Accuracy:
# tensor(0.2750, dtype=torch.float64)
# Loss:
# tensor(1.9989, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 186
# Accuracy:
# tensor(0.2833, dtype=torch.float64)
# Loss:
# tensor(1.9201, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 187
# Accuracy:
# tensor(0.2333, dtype=torch.float64)
# Loss:
# tensor(2.0213, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 188
# Accuracy:
# tensor(0.2833, dtype=torch.float64)
# Loss:
# tensor(1.9634, grad_fn=<NllLossBackward>)
# Epoch:
# 1
# Batch:
# 189
# Accuracy:
# tensor(0.2667, dtype=torch.float64)
# Loss:
# ...
# Loss:
# tensor(1.3808, grad_fn=<NllLossBackward>)
# Epoch:
# 26
# Batch:
# 223
# Accuracy:
# tensor(0.4333, dtype=torch.float64)
# Loss:
# tensor(1.5006, grad_fn=<NllLossBackward>)
# Epoch:
# 26
# Batch:
# 224
# Accuracy:
# tensor(0.6083, dtype=torch.float64)
# Loss:
# tensor(1.2560, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 0
# Validation Accuracy:
# tensor(0.3927, dtype=torch.float64)
# Accuracy:
# tensor(0.5333, dtype=torch.float64)
# Loss:
# tensor(1.3953, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 1
# Accuracy:
# tensor(0.5750, dtype=torch.float64)
# Loss:
# tensor(1.2289, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 2
# Accuracy:
# tensor(0.5167, dtype=torch.float64)
# Loss:
# tensor(1.3436, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 3
# Accuracy:
# tensor(0.5750, dtype=torch.float64)
# Loss:
# tensor(1.3132, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 4
# Accuracy:
# tensor(0.5250, dtype=torch.float64)
# Loss:
# tensor(1.3428, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 5
# Accuracy:
# tensor(0.5000, dtype=torch.float64)
# Loss:
# tensor(1.3382, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 6
# Accuracy:
# tensor(0.5250, dtype=torch.float64)
# Loss:
# tensor(1.3601, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 7
# Accuracy:
# tensor(0.5750, dtype=torch.float64)
# Loss:
# tensor(1.2527, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 8
# Accuracy:
# tensor(0.6083, dtype=torch.float64)
# Loss:
# tensor(1.1950, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 9
# Accuracy:
# tensor(0.5583, dtype=torch.float64)
# Loss:
# tensor(1.3215, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 10
# Accuracy:
# tensor(0.5583, dtype=torch.float64)
# Loss:
# tensor(1.2531, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 11
# Accuracy:
# tensor(0.5167, dtype=torch.float64)
# Loss:
# tensor(1.3061, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 12
# Accuracy:
# tensor(0.5583, dtype=torch.float64)
# Loss:
# tensor(1.3206, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 13
# Accuracy:
# tensor(0.5500, dtype=torch.float64)
# Loss:
# tensor(1.3468, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 14
# Accuracy:
# tensor(0.6583, dtype=torch.float64)
# Loss:
# tensor(1.1956, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 15
# Accuracy:
# tensor(0.5750, dtype=torch.float64)
# Loss:
# tensor(1.2511, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 16
# Accuracy:
# tensor(0.5417, dtype=torch.float64)
# Loss:
# tensor(1.3083, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 17
# Accuracy:
# tensor(0.5583, dtype=torch.float64)
# Loss:
# tensor(1.3290, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 18
# Accuracy:
# tensor(0.5583, dtype=torch.float64)
# Loss:
# tensor(1.3296, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 19
# Accuracy:
# tensor(0.4667, dtype=torch.float64)
# Loss:
# tensor(1.4197, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 20
# Accuracy:
# tensor(0.4417, dtype=torch.float64)
# Loss:
# tensor(1.4567, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 21
# Accuracy:
# tensor(0.5250, dtype=torch.float64)
# Loss:
# tensor(1.3791, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 22
# Accuracy:
# tensor(0.4833, dtype=torch.float64)
# Loss:
# tensor(1.3778, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 23
# Accuracy:
# tensor(0.4750, dtype=torch.float64)
# Loss:
# tensor(1.4149, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 24
# Accuracy:
# tensor(0.5250, dtype=torch.float64)
# Loss:
# tensor(1.3207, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 25
# Accuracy:
# tensor(0.5583, dtype=torch.float64)
# Loss:
# tensor(1.2607, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 26
# Accuracy:
# tensor(0.5667, dtype=torch.float64)
# Loss:
# tensor(1.2299, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 27
# Accuracy:
# tensor(0.5000, dtype=torch.float64)
# Loss:
# tensor(1.3345, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 28
# Accuracy:
# tensor(0.5250, dtype=torch.float64)
# Loss:
# tensor(1.3628, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 29
# Accuracy:
# tensor(0.5667, dtype=torch.float64)
# Loss:
# tensor(1.2691, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 30
# Validation Accuracy:
# tensor(0.3910, dtype=torch.float64)
# Accuracy:
# tensor(0.6250, dtype=torch.float64)
# Loss:
# tensor(1.2747, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 31
# Accuracy:
# tensor(0.5167, dtype=torch.float64)
# Loss:
# tensor(1.3419, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 32
# Accuracy:
# tensor(0.5083, dtype=torch.float64)
# Loss:
# tensor(1.3356, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 33
# Accuracy:
# tensor(0.5417, dtype=torch.float64)
# Loss:
# tensor(1.3566, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 34
# Accuracy:
# tensor(0.5500, dtype=torch.float64)
# Loss:
# tensor(1.3012, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 35
# Accuracy:
# tensor(0.5667, dtype=torch.float64)
# Loss:
# tensor(1.2229, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 36
# Accuracy:
# tensor(0.4750, dtype=torch.float64)
# Loss:
# tensor(1.3279, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 37
# Accuracy:
# tensor(0.4833, dtype=torch.float64)
# Loss:
# tensor(1.4294, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 38
# Accuracy:
# tensor(0.5167, dtype=torch.float64)
# Loss:
# tensor(1.4578, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 39
# Accuracy:
# tensor(0.4667, dtype=torch.float64)
# Loss:
# tensor(1.4865, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 40
# Accuracy:
# tensor(0.4333, dtype=torch.float64)
# Loss:
# tensor(1.5518, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 41
# Accuracy:
# tensor(0.5333, dtype=torch.float64)
# Loss:
# tensor(1.3248, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 42
# Accuracy:
# tensor(0.6000, dtype=torch.float64)
# Loss:
# tensor(1.3101, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 43
# Accuracy:
# tensor(0.5833, dtype=torch.float64)
# Loss:
# tensor(1.2909, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 44
# Accuracy:
# tensor(0.5500, dtype=torch.float64)
# Loss:
# tensor(1.2836, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 45
# Accuracy:
# tensor(0.4583, dtype=torch.float64)
# Loss:
# tensor(1.4574, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 46
# Accuracy:
# tensor(0.5500, dtype=torch.float64)
# Loss:
# tensor(1.4319, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 47
# Accuracy:
# tensor(0.6000, dtype=torch.float64)
# Loss:
# tensor(1.2169, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 48
# Accuracy:
# tensor(0.5333, dtype=torch.float64)
# Loss:
# tensor(1.2418, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 49
# Accuracy:
# tensor(0.5333, dtype=torch.float64)
# Loss:
# tensor(1.2955, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 50
# Accuracy:
# tensor(0.4833, dtype=torch.float64)
# Loss:
# tensor(1.4275, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 51
# Accuracy:
# tensor(0.5000, dtype=torch.float64)
# Loss:
# tensor(1.3245, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 52
# Accuracy:
# tensor(0.5333, dtype=torch.float64)
# Loss:
# tensor(1.3341, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 53
# Accuracy:
# tensor(0.5917, dtype=torch.float64)
# Loss:
# tensor(1.2630, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 54
# Accuracy:
# tensor(0.5583, dtype=torch.float64)
# Loss:
# tensor(1.3263, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 55
# Accuracy:
# tensor(0.5500, dtype=torch.float64)
# Loss:
# tensor(1.3091, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 56
# Accuracy:
# tensor(0.5417, dtype=torch.float64)
# Loss:
# tensor(1.2926, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 57
# Accuracy:
# tensor(0.5750, dtype=torch.float64)
# Loss:
# tensor(1.3226, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 58
# Accuracy:
# tensor(0.5417, dtype=torch.float64)
# Loss:
# tensor(1.3521, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 59
# Accuracy:
# tensor(0.4833, dtype=torch.float64)
# Loss:
# tensor(1.3193, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 60
# Validation Accuracy:
# tensor(0.3863, dtype=torch.float64)
# Accuracy:
# tensor(0.5167, dtype=torch.float64)
# Loss:
# tensor(1.3110, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 61
# Accuracy:
# tensor(0.4917, dtype=torch.float64)
# Loss:
# tensor(1.4602, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 62
# Accuracy:
# tensor(0.5583, dtype=torch.float64)
# Loss:
# tensor(1.3721, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 63
# Accuracy:
# tensor(0.4667, dtype=torch.float64)
# Loss:
# tensor(1.4751, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 64
# Accuracy:
# tensor(0.5083, dtype=torch.float64)
# Loss:
# tensor(1.3609, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 65
# Accuracy:
# tensor(0.4500, dtype=torch.float64)
# Loss:
# tensor(1.4003, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 66
# Accuracy:
# tensor(0.4250, dtype=torch.float64)
# Loss:
# tensor(1.4354, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 67
# Accuracy:
# tensor(0.5750, dtype=torch.float64)
# Loss:
# tensor(1.3576, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 68
# Accuracy:
# tensor(0.5583, dtype=torch.float64)
# Loss:
# tensor(1.3436, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 69
# Accuracy:
# tensor(0.4833, dtype=torch.float64)
# Loss:
# tensor(1.4153, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 70
# Accuracy:
# tensor(0.5417, dtype=torch.float64)
# Loss:
# tensor(1.3595, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 71
# Accuracy:
# tensor(0.4500, dtype=torch.float64)
# Loss:
# tensor(1.5170, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 72
# Accuracy:
# tensor(0.5250, dtype=torch.float64)
# Loss:
# tensor(1.2932, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 73
# Accuracy:
# tensor(0.5250, dtype=torch.float64)
# Loss:
# tensor(1.3823, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 74
# Accuracy:
# tensor(0.4583, dtype=torch.float64)
# Loss:
# tensor(1.3663, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 75
# Accuracy:
# tensor(0.5083, dtype=torch.float64)
# Loss:
# tensor(1.4525, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 76
# Accuracy:
# tensor(0.5667, dtype=torch.float64)
# Loss:
# tensor(1.2581, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 77
# Accuracy:
# tensor(0.5000, dtype=torch.float64)
# Loss:
# tensor(1.4057, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 78
# Accuracy:
# tensor(0.5750, dtype=torch.float64)
# Loss:
# tensor(1.2588, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 79
# Accuracy:
# tensor(0.5000, dtype=torch.float64)
# Loss:
# tensor(1.3011, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 80
# Accuracy:
# tensor(0.5083, dtype=torch.float64)
# Loss:
# tensor(1.3627, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 81
# Accuracy:
# tensor(0.4750, dtype=torch.float64)
# Loss:
# tensor(1.3701, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 82
# Accuracy:
# tensor(0.5333, dtype=torch.float64)
# Loss:
# tensor(1.2699, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 83
# Accuracy:
# tensor(0.5083, dtype=torch.float64)
# Loss:
# tensor(1.2839, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 84
# Accuracy:
# tensor(0.5583, dtype=torch.float64)
# Loss:
# tensor(1.2638, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 85
# Accuracy:
# tensor(0.4417, dtype=torch.float64)
# Loss:
# tensor(1.3243, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 86
# Accuracy:
# tensor(0.5083, dtype=torch.float64)
# Loss:
# tensor(1.3265, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 87
# Accuracy:
# tensor(0.5083, dtype=torch.float64)
# Loss:
# tensor(1.3589, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 88
# Accuracy:
# tensor(0.5833, dtype=torch.float64)
# Loss:
# tensor(1.3087, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 89
# Accuracy:
# tensor(0.5417, dtype=torch.float64)
# Loss:
# tensor(1.3071, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 90
# Validation Accuracy:
# tensor(0.3850, dtype=torch.float64)
# Accuracy:
# tensor(0.5167, dtype=torch.float64)
# Loss:
# tensor(1.3173, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 91
# Accuracy:
# tensor(0.4583, dtype=torch.float64)
# Loss:
# tensor(1.4629, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 92
# Accuracy:
# tensor(0.4917, dtype=torch.float64)
# Loss:
# tensor(1.3762, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 93
# Accuracy:
# tensor(0.4833, dtype=torch.float64)
# Loss:
# tensor(1.5168, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 94
# Accuracy:
# tensor(0.5000, dtype=torch.float64)
# Loss:
# tensor(1.3080, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 95
# Accuracy:
# tensor(0.5750, dtype=torch.float64)
# Loss:
# tensor(1.1968, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 96
# Accuracy:
# tensor(0.5083, dtype=torch.float64)
# Loss:
# tensor(1.3506, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 97
# Accuracy:
# tensor(0.5083, dtype=torch.float64)
# Loss:
# tensor(1.3564, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 98
# Accuracy:
# tensor(0.4917, dtype=torch.float64)
# Loss:
# tensor(1.4374, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 99
# Accuracy:
# tensor(0.6667, dtype=torch.float64)
# Loss:
# tensor(1.1151, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 100
# Accuracy:
# tensor(0.5583, dtype=torch.float64)
# Loss:
# tensor(1.3087, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 101
# Accuracy:
# tensor(0.5083, dtype=torch.float64)
# Loss:
# tensor(1.4068, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 102
# Accuracy:
# tensor(0.5500, dtype=torch.float64)
# Loss:
# tensor(1.2429, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 103
# Accuracy:
# tensor(0.4917, dtype=torch.float64)
# Loss:
# tensor(1.4283, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 104
# Accuracy:
# tensor(0.4417, dtype=torch.float64)
# Loss:
# tensor(1.4432, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 105
# Accuracy:
# tensor(0.5250, dtype=torch.float64)
# Loss:
# tensor(1.2815, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 106
# Accuracy:
# tensor(0.4750, dtype=torch.float64)
# Loss:
# tensor(1.3386, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 107
# Accuracy:
# tensor(0.5750, dtype=torch.float64)
# Loss:
# tensor(1.3037, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 108
# Accuracy:
# tensor(0.4750, dtype=torch.float64)
# Loss:
# tensor(1.3851, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 109
# Accuracy:
# tensor(0.4667, dtype=torch.float64)
# Loss:
# tensor(1.4369, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 110
# Accuracy:
# tensor(0.5667, dtype=torch.float64)
# Loss:
# tensor(1.2499, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 111
# Accuracy:
# tensor(0.5833, dtype=torch.float64)
# Loss:
# tensor(1.2909, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 112
# Accuracy:
# tensor(0.5667, dtype=torch.float64)
# Loss:
# tensor(1.3857, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 113
# Accuracy:
# tensor(0.4583, dtype=torch.float64)
# Loss:
# tensor(1.4753, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 114
# Accuracy:
# tensor(0.5250, dtype=torch.float64)
# Loss:
# tensor(1.3813, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 115
# Accuracy:
# tensor(0.5000, dtype=torch.float64)
# Loss:
# tensor(1.3635, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 116
# Accuracy:
# tensor(0.4917, dtype=torch.float64)
# Loss:
# tensor(1.3554, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 117
# Accuracy:
# tensor(0.5167, dtype=torch.float64)
# Loss:
# tensor(1.3445, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 118
# Accuracy:
# tensor(0.4667, dtype=torch.float64)
# Loss:
# tensor(1.4077, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 119
# Accuracy:
# tensor(0.5167, dtype=torch.float64)
# Loss:
# tensor(1.4297, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 120
# Validation Accuracy:
# tensor(0.3860, dtype=torch.float64)
# Accuracy:
# tensor(0.4000, dtype=torch.float64)
# Loss:
# tensor(1.4865, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 121
# Accuracy:
# tensor(0.5417, dtype=torch.float64)
# Loss:
# tensor(1.4133, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 122
# Accuracy:
# tensor(0.5250, dtype=torch.float64)
# Loss:
# tensor(1.3256, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 123
# Accuracy:
# tensor(0.5833, dtype=torch.float64)
# Loss:
# tensor(1.2578, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 124
# Accuracy:
# tensor(0.5417, dtype=torch.float64)
# Loss:
# tensor(1.3359, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 125
# Accuracy:
# tensor(0.4917, dtype=torch.float64)
# Loss:
# tensor(1.4072, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 126
# Accuracy:
# tensor(0.5917, dtype=torch.float64)
# Loss:
# tensor(1.3029, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 127
# Accuracy:
# tensor(0.5500, dtype=torch.float64)
# Loss:
# tensor(1.3512, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 128
# Accuracy:
# tensor(0.5417, dtype=torch.float64)
# Loss:
# tensor(1.3497, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 129
# Accuracy:
# tensor(0.5250, dtype=torch.float64)
# Loss:
# tensor(1.4191, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 130
# Accuracy:
# tensor(0.5417, dtype=torch.float64)
# Loss:
# tensor(1.2802, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 131
# Accuracy:
# tensor(0.4667, dtype=torch.float64)
# Loss:
# tensor(1.4541, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 132
# Accuracy:
# tensor(0.5000, dtype=torch.float64)
# Loss:
# tensor(1.4066, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 133
# Accuracy:
# tensor(0.5667, dtype=torch.float64)
# Loss:
# tensor(1.3110, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 134
# Accuracy:
# tensor(0.5250, dtype=torch.float64)
# Loss:
# tensor(1.3520, grad_fn=<NllLossBackward>)
# Epoch:
# 27
# Batch:
# 135

# %% [markdown]
# ### Predictions ###

# %%
with torch.no_grad():
        output = cnn(test_x)

# %%
prob = output.tolist()
predictions = np.argmax(prob, axis=1)

pred_label = []
for i in predictions:
    pred_label.append(classes[i])
from numpy import asarray
from numpy import savetxt
import pandas as pd
# define id
id = np.arange(0,20000)
labels=np.asarray(pred_label)
labels.reshape(20000,1)
print(labels.shape)
d = {'Category':labels}
df = pd.DataFrame(data=d)
df.to_csv('submission.csv')
# Out:
# (20000,)
